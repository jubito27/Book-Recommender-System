# %%
print("Let's Start")
# Out:
# Let's Start

# %%
import pandas as pd

df1 = pd.read_csv('Books.csv')
df1 = df1.drop(columns=['Image-URL-S' , 'Image-URL-M' , 'Image-URL-L'])
df1.head()
# Out:
# C:\Users\Abhishek sharma\AppData\Local\Temp\ipykernel_33528\1893452743.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('Books.csv')
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# ...

# %%
df2 = pd.read_csv('Ratings.csv')
df2.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
df3 = pd.read_csv('Users.csv')
df3.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (271360, 5)
# (1149780, 3)
# (278858, 3)

# %% [markdown]
# **popularity based rating system**

# %%
top_50 = df2[df2['Book-Rating'] == 10][:80]

# %%
isbn = top_50['ISBN'].to_list()

# %%
df = df1.merge(top_50 , on='ISBN')
df = df[:50]
df.shape
# Out:
# (50, 7)

# %%
df.head()
# Out:
#          ISBN                                       Book-Title  \
# 0  0446310786                            To Kill a Mockingbird
# 1  0060930187      The Bell Jar : A Novel (Perennial Classics)
# 2  0385720920                                            Choke
# 3  0812550307  The Fires of Heaven (The Wheel of Time, Book 5)
# 4  081297106X      Reading Lolita in Tehran: A Memoir in Books
#
#        Book-Author Year-Of-Publication                      Publisher  \
# 0       Harper Lee                1988     Little Brown &amp; Company
# 1     Sylvia Plath                2000                      Perennial
# 2  CHUCK PALAHNIUK                2002                         Anchor
# 3    Robert Jordan                1994                    Tor Fantasy
# 4      Azar Nafisi                2003  Random House Trade Paperbacks
#
#    User-ID  Book-Rating
# 0   276953           10
# 1   276986           10
# 2   277051           10
# 3   276964           10
# 4   277107           10

# %%
import pickle

pickle.dump(df , open('top_50_data' , 'wb'))
